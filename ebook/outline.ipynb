# %% [markdown]
# ## Outline
#
# #### [Introduction](./concepts/00_intro.ipynb) (Aug 30)
# * Parallelism
# * Concurrency versus Parallelism
#
# #### Tool 1: [Parallel Python](./examples/01_joblib.ipynb)  (Aug 30)
# * A First Program
# * Python parallel processes
# * Concurrency versus parallelism
# * The Global Interpreter Lock and python threads
#
# #### Concept 1: [Strong Scaling](./concepts/01_strong_scaling.ipynb) (Sep. 6)
# * Amdahls Law
# * Speedup
# * Parallel Efficiency
#
# #### Concept 2: [CPU Parallelism: Multicore](./concepts/02_moores_multicore.ipynb) (Sep. 11)
# * What is a CPU? (evolution of CPUs, motivation for parallelism, Moore's Law)
# * Multicore
#     * Shared-memory
#
# ####  Tool 2: [OpenMP](./examples/02_open_mp.ipynb) (Sep. 11)
# * What is OpenMP (parallel C/Fortran on multicore, shared-memory architectures)
# * Serial to Parallel Refactoring
# * System overview
#     * Preprocessor
#     * Library
#     * Runtime
# * Example #parallel directive
#     * Blocks and scoping
#     * Interacting with the environment
# * Reference Materials : https://hpc-tutorials.llnl.gov/openmp/
#
# #### Concept 3: [Memory Hierarchy](./concepts/memory_hierarchy.ipynb) (Sep 13)
# * Latencies
# * Cache coherency
# * Row versus column order
# * LM Bench
# * **Read**: https://siboehm.com/articles/22/Fast-MMM-on-CPU
#
# ####  Tool 3: Cilk  (Sep. 15)
#     * fork/join parallelism
#     * loop parallelism
#     * work stealing and scheduling
#
# #### Concept 3: [Factors Against Parallelism](nbconcepts/03_factors.ipynb) (Sep 18)
# * Interference
# * Skew
# * Startup costs
# * Overlap
# * top/htop processor utilization
#
# #### Concept 4: [Loop Parallelism](nbconcepts/04_loop_optimization.ipynb)
#     * Chunks
#     * Scoping and thread local variables
#     * Loop dependencies
#     * Loop fusion
#     * Loop fission
#     * Skew and dynamic scheduling (TODO)
#
# #### Concept 5: Cache Hierarchy
#
# #### Concept 6: CPU Parallelism: ILP
#     * ILP
#         * Pipelines
#         * Vectorization
#         * (XX) Other Sources (out-of-order execution, branch prediction, speculative execution)
#
# #### Tool 3: Vector Intrinsics
#   * TODO
#
# #### Concept 7: NUMA
#   * NUMA architecture
#   * Demonstarting Example (TODO)
#   * (XX) Detecting and Programming to NUMA
#     * numactl and libnuma
#     * different between NUMA and hierarchy heterogeneity
#
# #### Concept 8: Roofline

# %% [markdown]
# #### Concept 9: Threads
#   * Threads vs. Processes
#   * Shared memory
#
# #### Tool 4: Java Thread Programming
#
# #### Concept 10: Thread Synchronization
#
# #### Concept 11: Mutual Exclusion
#     * Bakery algorithm
#     * Fast Mutual Exclusion

# %% [markdown]
# #### Concept 12: Distributed Memory Architectures
#     * Distributed Memory Programming
#         * Message Passing
#         * Remote Procedure Calls
#     * Client/Server and Service-Oriented Architectures
#     * Clusters and Supercomputers
#     * Clouds and Frameworks
# #### Tool 5: MPI
#     * Send/Receive
#     * Deadlock
#     * Collective Operations
# #### Concept 13: Deadlock
# #### Concept 14: Data-Parallel Cloud Programming
#     * Map/Reduce: I/O Streaming
#     * In-Memory Computing
#     * Parallel Python
# #### Concept 15: Distributed Arrays
# #### Tool 6: Dask
# #### Concept 16: Distrbuted Data-Frames
# #### Concept 17: Resilient-Distributed Data Structures
#     * Lineage
#     * Recovery
#     * Checkpoints
# #### Tool 7: Spark
# #### Concept 18: Barriers and BSP
# #### Concept 19: Remote Functions
# #### Tool 8: Ray
# #### Concept 20: Actors
#   * TODO fix deadlock example or abandon

# %%
#### Concepts that didn't make it yet

Simultaneous multithreading

### What happened to numba?
